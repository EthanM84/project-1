# %%
#import dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
data_file = Path("Resources\\us_births_2016_2021.csv")

# %%
us_births_df = pd.read_csv("us_births_2016_2021.csv")
us_births_df
# Out:
#         State State Abbreviation  Year Gender  \
# 0     Alabama                 AL  2016      F
# 1     Alabama                 AL  2016      F
# 2     Alabama                 AL  2016      F
# 3     Alabama                 AL  2016      F
# 4     Alabama                 AL  2016      F
# ...       ...                ...   ...    ...
# 5491  Wyoming                 WY  2021      M
# 5492  Wyoming                 WY  2021      M
# 5493  Wyoming                 WY  2021      M
# 5494  Wyoming                 WY  2021      M
# 5495  Wyoming                 WY  2021      M
#
#                               Education Level of Mother  Education Level Code  \
# 0                                     8th grade or less                     1
# 1                9th through 12th grade with no diploma                     2
# 2                 High school graduate or GED completed                     3
# 3                 Some college credit, but not a degree                     4
# ...

# %%
us_births_df['Average Age of Mother (years)'] = us_births_df['Average Age of Mother (years)'].astype(float).astype(int)
us_births_df
# Out:
#         State State Abbreviation  Year Gender  \
# 0     Alabama                 AL  2016      F
# 1     Alabama                 AL  2016      F
# 2     Alabama                 AL  2016      F
# 3     Alabama                 AL  2016      F
# 4     Alabama                 AL  2016      F
# ...       ...                ...   ...    ...
# 5491  Wyoming                 WY  2021      M
# 5492  Wyoming                 WY  2021      M
# 5493  Wyoming                 WY  2021      M
# 5494  Wyoming                 WY  2021      M
# 5495  Wyoming                 WY  2021      M
#
#                               Education Level of Mother  Education Level Code  \
# 0                                     8th grade or less                     1
# 1                9th through 12th grade with no diploma                     2
# 2                 High school graduate or GED completed                     3
# 3                 Some college credit, but not a degree                     4
# ...

# %%
mothers_age = us_births_df.groupby(["Average Age of Mother (years)"])['Average Birth Weight (g)'].count()
mothers_age
# Out:
# Average Age of Mother (years)
# 23     56
# 24    262
# 25    355
# 26    446
# 27    480
# 28    635
# 29    759
# 30    730
# 31    491
# 32    499
# 33    517
# 34    246
# 35     20
# Name: Average Birth Weight (g), dtype: int64

# %%
bby_plot = mothers_age.plot(kind="bar", color='b', figsize=(10,8), fontsize = 14)
plt.title = ("Average Age of Mother vs Birthweight (g)")
plt.xlabel("Age",fontsize = 15)
plt.ylabel("Weight (grams)",fontsize = 15)

ticks = range(0, 23, 36)
labels = ticks
plt.xticks(ticks, labels)
                           
plt.show()
plt.tight_layout()

bby_plot
# Out:
# <Axes: xlabel='Age', ylabel='Weight (grams)'>
